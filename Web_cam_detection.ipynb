# %%
from PIL import Image

# %%
from keras.applications.vgg16 import preprocess_input

# %%
import base64

# %%
from io import BytesIO

# %%
import json

# %%
import  random

# %%
import cv2

# %%
from keras.models import load_model

# %%
import numpy as np

# %%
from keras.preprocessing import image

# %%
model = load_model('face_determination_model.h5')

# %%
#loading cascades

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
def face_extractor(img):
    faces = face_cascade.detectMultiScale(img, 1.3, 5)
    if faces is ():
        return None
    #crop all faces found
    for (x,y,w,h) in faces:
        cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,255), 2)
        cropped_face = img[y:y+h,x:x+w]
    return cropped_face
# Out:
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\s8908\AppData\Local\Temp\ipykernel_8608\1933924516.py:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
#face recognition with webcam

# %%
video_capture = cv2.VideoCapture(0)

# %%
while True:
    _, frame = video_capture.read()
    face = face_extractor(frame)
    if type(face) is np.ndarray:
        face = cv2.resize(face, (244,244))
        im = Image.fromarray(face, 'RGB')
        img_array = np.array(im)
        img_array = np.expand_dims(img_array, axis=0)
        pred = model.predict(img_array)
        print(pred)
        name = "None matching"
        if (pred[0][1]>0.5):
            name = 'Saurabh-R'
            cv2.putText(frame, name, (50,50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2) 
        else:
            cv2.putText(frame,"No face found", (50,50), cv2.FONT_HERSHEY_DUPLEX, 1 ,(0,255,0), 2)
        cv2.imshow('face-recognition',frame)
    if cv2.waitKey(1) & 0XFF == ord('q'):
        break
video_capture.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 421ms/step
# [[1.000000e+00 3.936954e-37]]
# 1/1 [==============================] - 0s 163ms/step
# [[9.995066e-01 4.933564e-04]]
# 1/1 [==============================] - 0s 147ms/step
# [[1.000000e+00 7.359268e-22]]
# 1/1 [==============================] - 0s 143ms/step
# [[1.1418921e-15 1.0000000e+00]]
# 1/1 [==============================] - 0s 175ms/step
# [[1.000000e+00 9.407736e-13]]
# 1/1 [==============================] - 0s 146ms/step
# [[1.0000000e+00 1.0014965e-30]]
# 1/1 [==============================] - 0s 142ms/step
# [[9.998542e-01 1.457733e-04]]
# 1/1 [==============================] - 0s 141ms/step
# [[3.9281393e-19 1.0000000e+00]]
# 1/1 [==============================] - 0s 157ms/step
# [[9.99896765e-01 1.03273436e-04]]
# 1/1 [==============================] - 0s 141ms/step
# [[1.8458797e-17 1.0000000e+00]]
# 1/1 [==============================] - 0s 143ms/step
# [[1.000000e+00 3.485702e-21]]
# 1/1 [==============================] - 0s 167ms/step
# [[9.999547e-01 4.533652e-05]]
# 1/1 [==============================] - 0s 144ms/step
# [[1. 0.]]
# 1/1 [==============================] - 0s 251ms/step
# [[2.385139e-18 1.000000e+00]]
# 1/1 [==============================] - 0s 142ms/step
# [[1.0000000e+00 2.1075842e-34]]
# 1/1 [==============================] - 0s 152ms/step
# [[1.00000000e+00 1.02172956e-13]]
# [[1.0000000e+00 8.9107995e-14]]
# 1/1 [==============================] - 0s 237ms/step
# [[1.000000e+00 9.523293e-33]]
# 1/1 [==============================] - 0s 220ms/step
# [[1.0000000e+00 2.1841286e-20]]
# 1/1 [==============================] - 0s 226ms/step
# [[1.0000000e+00 3.5929665e-19]]
# 1/1 [==============================] - 0s 244ms/step
# [[1.0000000e+00 1.4030512e-16]]
# 1/1 [==============================] - 0s 290ms/step
# [[1.0000000e+00 5.1339153e-29]]
# 1/1 [==============================] - 0s 279ms/step
# [[1.0000000e+00 1.1412433e-30]]
# 1/1 [==============================] - 0s 236ms/step
# [[1.000000e+00 8.788816e-17]]
# 1/1 [==============================] - 0s 277ms/step
# [[5.686647e-08 1.000000e+00]]
# 1/1 [==============================] - 0s 255ms/step
# [[0.74272007 0.25727996]]
# 1/1 [==============================] - 0s 262ms/step
# [[1.00000e+00 6.42458e-28]]
# 1/1 [==============================] - 0s 241ms/step
# [[1.00000000e+00 1.01014145e-29]]
# 1/1 [==============================] - 0s 269ms/step
# [[1.4214159e-16 1.0000000e+00]]
# 1/1 [==============================] - 0s 260ms/step
# [[1.0000000e+00 4.6391123e-30]]
# 1/1 [==============================] - 0s 282ms/step
# [[3.2240505e-06 9.9999678e-01]]
# 1/1 [==============================] - 0s 262ms/step
# [[7.070033e-05 9.999293e-01]]
# 1/1 [==============================] - 0s 263ms/step
# [[5.032513e-18 1.000000e+00]]
# 1/1 [==============================] - 0s 255ms/step
# [[3.793281e-18 1.000000e+00]]
# 1/1 [==============================] - 0s 256ms/step
# [[1.1933338e-21 1.0000000e+00]]
# 1/1 [==============================] - 0s 247ms/step
# [[1.9108335e-18 1.0000000e+00]]
# 1/1 [==============================] - 0s 243ms/step
# [[8.584961e-17 1.000000e+00]]
# 1/1 [==============================] - 0s 210ms/step
# [[2.9567402e-15 1.0000000e+00]]
# 1/1 [==============================] - 0s 263ms/step
# [[9.180689e-06 9.999908e-01]]
# 1/1 [==============================] - 0s 240ms/step
# [[0.00448565 0.99551433]]
# 1/1 [==============================] - 0s 268ms/step
# [[0.00207188 0.99792814]]
# 1/1 [==============================] - 0s 251ms/step
# [[2.336884e-10 1.000000e+00]]
# 1/1 [==============================] - 0s 240ms/step
# [[2.0732999e-22 1.0000000e+00]]
# 1/1 [==============================] - 0s 255ms/step
# [[1.0000000e+00 5.1111695e-29]]
# 1/1 [==============================] - 0s 266ms/step
# [[1.0000000e+00 1.1950428e-20]]
# 1/1 [==============================] - 0s 273ms/step
# [[1.0495061e-04 9.9989510e-01]]
# 1/1 [==============================] - 0s 294ms/step
# [[9.999999e-01 6.636137e-08]]
# 1/1 [==============================] - 0s 263ms/step
# [[1.000000e+00 6.003181e-23]]
# 1/1 [==============================] - 0s 209ms/step
# [[1.0000000e+00 2.1895192e-11]]
# 1/1 [==============================] - 0s 145ms/step
# [[1.000000e+00 2.972688e-29]]
# 1/1 [==============================] - 0s 191ms/step
# [[1.0000000e+00 4.4033154e-21]]
# 1/1 [==============================] - 0s 150ms/step
# [[3.8632287e-19 1.0000000e+00]]

# %%
cv2.__version__
# Out:
# '4.8.0'
